# %% [markdown]
# <a href="https://colab.research.google.com/github/pksX01/AI-practice/blob/main/Gen%20AI/PandasAI_Exp_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#from google.colab import files
#files.upload() # Upload your Kaggle API token

# %%
'''!pip install -q kaggle
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json'''
# Out:
# '!pip install -q kaggle\n!mkdir -p ~/.kaggle\n!cp kaggle.json ~/.kaggle/\n!chmod 600 ~/.kaggle/kaggle.json'

# %%
#!kaggle competitions download -c amex-default-prediction

# %%
#!unzip /content/amex-default-prediction.zip

# %%
# !pip install pandasai
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.5/162.5 kB 3.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 43.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 324.1/324.1 kB 28.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 53.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 74.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 8.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 8.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 6.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pillow
#     Found existing installation: Pillow 9.4.0
#     Uninstalling Pillow-9.4.0:
#       Successfully uninstalled Pillow-9.4.0
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.0.3
#     Uninstalling pandas-2.0.3:
#       Successfully uninstalled pandas-2.0.3
# ...

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-21873227-e6bd-4d79-92c0-84779d5df292" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-21873227-e6bd-4d79-92c0-84779d5df292">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !unzip /content/fraudTest.csv.zip
# Out:
# Archive:  /content/fraudTest.csv.zip
#   inflating: fraudTest.csv

# %%
from pandasai.llm import GooglePalm
from google.colab import userdata
from pandasai import SmartDataframe

GOOGLE_API_KEY=userdata.get('GOOGLE_API_KEY')

llm = GooglePalm(api_key=GOOGLE_API_KEY)

sdf = SmartDataframe("/content/fraudTest.csv", config={"llm": llm})

# %%
import pandas as pd
df = pd.read_csv("/content/fraudTest.csv")

# %%
df.head()
# Out:
#    Unnamed: 0 trans_date_trans_time            cc_num  \
# 0           0   2020-06-21 12:14:25  2291163933867244
# 1           1   2020-06-21 12:14:33  3573030041201292
# 2           2   2020-06-21 12:14:53  3598215285024754
# 3           3   2020-06-21 12:15:15  3591919803438423
# 4           4   2020-06-21 12:15:17  3526826139003047
#
#                                merchant        category    amt   first  \
# 0                 fraud_Kirlin and Sons   personal_care   2.86    Jeff
# 1                  fraud_Sporer-Keebler   personal_care  29.84  Joanne
# 2  fraud_Swaniawski, Nitzsche and Welch  health_fitness  41.28  Ashley
# 3                     fraud_Haley Group        misc_pos  60.05   Brian
# 4                 fraud_Johnston-Casper          travel   3.19  Nathan
#
#        last gender                       street  ...      lat      long  \
# 0   Elliott      M            351 Darlene Green  ...  33.9659  -80.9355
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'trans_date_trans_time', 'cc_num', 'merchant', 'category',
#        'amt', 'first', 'last', 'gender', 'street', 'city', 'state', 'zip',
#        'lat', 'long', 'city_pop', 'job', 'dob', 'trans_num', 'unix_time',
#        'merch_lat', 'merch_long', 'is_fraud'],
#       dtype='object')

# %%
sdf.chat("explain the data in brief")
# Out:
# 'The data contains 555719 rows and 23 columns. The data is about credit card transactions. The columns include transaction date, transaction time, credit card number, merchant, category, amount, first name, last name, gender, street, city, state, zip, latitude, longitude, city population, job, date of birth, transaction number, unix time, merchant latitude, merchant longitude, and is fraud.'

# %%
sdf.chat("plot a chart to show number of fraud transactions for each merchant")
# Out:
# ERROR:pandasai.helpers.logger:Pipeline failed on step 3: argument of type 'NoneType' is not iterable
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/pandasai/pipelines/chat/generate_chat_pipeline.py", line 310, in run
#     ).run(input)
#   File "/usr/local/lib/python3.10/dist-packages/pandasai/pipelines/pipeline.py", line 137, in run
#     raise e
#   File "/usr/local/lib/python3.10/dist-packages/pandasai/pipelines/pipeline.py", line 101, in run
#     step_output = logic.execute(
#   File "/usr/local/lib/python3.10/dist-packages/pandasai/pipelines/chat/code_generator.py", line 33, in execute
#     code = pipeline_context.config.llm.generate_code(input, pipeline_context)
#   File "/usr/local/lib/python3.10/dist-packages/pandasai/llm/base.py", line 202, in generate_code
#     return self._extract_code(response)
#   File "/usr/local/lib/python3.10/dist-packages/pandasai/llm/base.py", line 121, in _extract_code
# ...

# %%
sdf.chat("plot a histogram to show number of fraud transactions for each merchant")
# Out:
# ERROR:pandasai.helpers.logger:Pipeline failed on step 3: argument of type 'NoneType' is not iterable
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/pandasai/pipelines/chat/generate_chat_pipeline.py", line 310, in run
#     ).run(input)
#   File "/usr/local/lib/python3.10/dist-packages/pandasai/pipelines/pipeline.py", line 137, in run
#     raise e
#   File "/usr/local/lib/python3.10/dist-packages/pandasai/pipelines/pipeline.py", line 101, in run
#     step_output = logic.execute(
#   File "/usr/local/lib/python3.10/dist-packages/pandasai/pipelines/chat/code_generator.py", line 33, in execute
#     code = pipeline_context.config.llm.generate_code(input, pipeline_context)
#   File "/usr/local/lib/python3.10/dist-packages/pandasai/llm/base.py", line 202, in generate_code
#     return self._extract_code(response)
#   File "/usr/local/lib/python3.10/dist-packages/pandasai/llm/base.py", line 121, in _extract_code
# ...

# %%
sdf.chat("tell me the number of fraud transactions for each merchant")
# Out:
#                                  merchant  fraud_count
# 0                   fraud_Kirlin and Sons         2145
# 1                    fraud_Sporer-Keebler         2145
# 2    fraud_Swaniawski, Nitzsche and Welch         2145
# 3                       fraud_Haley Group         2145
# 4                   fraud_Johnston-Casper         2145
# ..                                    ...          ...
# 688    fraud_Hagenes, Hermann and Stroman         2145
# 689                 fraud_Hermann-Gaylord         2145
# 690                     fraud_Mante Group         2145
# 691                 fraud_Corwin-Gorczany         2145
# 692                fraud_McCullough Group         2145
#
# [693 rows x 2 columns]

# %%
sdf.chat("can you plot for above result")
# Out:
# '/content/exports/charts/temp_chart.png'

# %%
sdf.chat("plot a histogram of number of fraudulent transaction for each city")
# Out:
# ERROR:pandasai.helpers.logger:Pipeline failed on step 3: argument of type 'NoneType' is not iterable
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/pandasai/pipelines/chat/generate_chat_pipeline.py", line 310, in run
#     ).run(input)
#   File "/usr/local/lib/python3.10/dist-packages/pandasai/pipelines/pipeline.py", line 137, in run
#     raise e
#   File "/usr/local/lib/python3.10/dist-packages/pandasai/pipelines/pipeline.py", line 101, in run
#     step_output = logic.execute(
#   File "/usr/local/lib/python3.10/dist-packages/pandasai/pipelines/chat/code_generator.py", line 33, in execute
#     code = pipeline_context.config.llm.generate_code(input, pipeline_context)
#   File "/usr/local/lib/python3.10/dist-packages/pandasai/llm/base.py", line 202, in generate_code
#     return self._extract_code(response)
#   File "/usr/local/lib/python3.10/dist-packages/pandasai/llm/base.py", line 121, in _extract_code
# ...
