# %% [markdown]
# <a href="https://colab.research.google.com/github/pksX01/AI-practice/blob/main/Gen%20AI/Langchain_pyspark.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pyspark
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.9/316.9 MB 4.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pyspark: filename=pyspark-3.5.0-py2.py3-none-any.whl size=317425344 sha256=38d2a1dbdda0ef55efb052b03caac7ed3d9d546ca512e0ead3e3464eabc024b5
#   Stored in directory: /root/.cache/pip/wheels/41/4e/10/c2cf2467f71c678cfc8a6b9ac9241e5e44a01940da8fbb17fc
# Successfully built pyspark
# ...

# %%
# !pip install langchain
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 8.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 7.3 MB/s eta 0:00:00
# ...

# %%
# !CMAKE_ARGS="-DLLAMA_CUBLAS=on" FORCE_CMAKE=1 pip install llama-cpp-python
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 26.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 5.9 MB/s eta 0:00:00
# ...
#   Created wheel for llama-cpp-python: filename=llama_cpp_python-0.2.11-cp310-cp310-manylinux_2_35_x86_64.whl size=6423499 sha256=0ac541d7c85104d1d8edb2f25191c8fa9000be0fb949aff12a4178118656db95
#   Stored in directory: /root/.cache/pip/wheels/dc/42/77/a3ab0d02700427ea364de5797786c0272779dce795f62c3bc2
# Successfully built llama-cpp-python
# ...

# %%
#!git clone https://github.com/ggerganov/llama.cpp.git

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-5528e5d3-ca93-4fba-920a-c3d74857dcab" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5528e5d3-ca93-4fba-920a-c3d74857dcab">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.getOrCreate()

# %%
# !rm -r /content/spark-warehouse/langchain_spark.db
# Out:
# rm: cannot remove '/content/spark-warehouse/langchain_spark.db': No such file or directory

# %%
schema = 'langchain_spark'
tbl_nm = 'stroke_data'
spark.sql(f"CREATE DATABASE IF NOT EXISTS {schema}")
df = spark.read.csv('/content/healthcare-dataset-stroke-data.csv', header=True, inferSchema=True)
df.write.saveAsTable(f"{schema}.{tbl_nm}")

# %%
spark.table(f"{schema}.{tbl_nm}").show()
# Out:
# +-----+------+----+------------+-------------+------------+-------------+--------------+-----------------+----+---------------+------+
# |   id|gender| age|hypertension|heart_disease|ever_married|    work_type|Residence_type|avg_glucose_level| bmi| smoking_status|stroke|
# +-----+------+----+------------+-------------+------------+-------------+--------------+-----------------+----+---------------+------+
# | 9046|  Male|67.0|           0|            1|         Yes|      Private|         Urban|           228.69|36.6|formerly smoked|     1|
# |51676|Female|61.0|           0|            0|         Yes|Self-employed|         Rural|           202.21| N/A|   never smoked|     1|
# |31112|  Male|80.0|           0|            1|         Yes|      Private|         Rural|           105.92|32.5|   never smoked|     1|
# |60182|Female|49.0|           0|            0|         Yes|      Private|         Urban|           171.23|34.4|         smokes|     1|
# ...

# %%
from langchain.agents import create_spark_sql_agent
from langchain.agents.agent_toolkits import SparkSQLToolkit
from langchain.utilities import SparkSQL

# %%
from langchain.llms import LlamaCpp

# %%
#spark.sql(f"drop table {schema}.{tbl_nm}")
# Out:
# DataFrame[]

# %%
#from langchain.callbacks.manager import CallbackManager
#from langchain.callbacks.streaming_stdout import StreamingStdOutCallbackHandler
#callback_manager = CallbackManager([StreamingStdOutCallbackHandler])

# %%
#!pip install transformers accelerate optimum auto-gptq
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 18.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.1/258.1 kB 30.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.0/301.0 kB 37.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 44.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 56.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 52.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 6.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.6/519.6 kB 42.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.6/85.6 kB 10.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 30.1 MB/s eta 0:00:00
# ...

# %%
# !pip install huggingface_hub

# %%
from huggingface_hub import hf_hub_download
#hf_hub_download(repo_id='TheBloke/Llama-2-7B-GGUF', filename='llama-2-7b.Q2_K.gguf')
hf_hub_download(repo_id='TheBloke/Llama-2-7b-Chat-GGUF', filename='llama-2-7b-chat.Q2_K.gguf')
# Out:
# ...
# '/root/.cache/huggingface/hub/models--TheBloke--Llama-2-7b-Chat-GGUF/snapshots/9ca625120374ddaae21f067cb006517d14dc91a6/llama-2-7b-chat.Q2_K.gguf'

# %%
llm = LlamaCpp(
    #model_path = '/root/.cache/huggingface/hub/models--TheBloke--Llama-2-7B-GGUF/snapshots/61289dfe7c8355b61c7ddd6178e89300999b11eb/llama-2-7b.Q2_K.gguf',
    model_path='/root/.cache/huggingface/hub/models--TheBloke--Llama-2-7b-Chat-GGUF/snapshots/9ca625120374ddaae21f067cb006517d14dc91a6/llama-2-7b-chat.Q2_K.gguf',
    n_gpu_layers=40,
    n_batch=512,
    n_ctx=1024,
    #callback_manager=callback_manager,
    verbose=True
)
# Out:
# AVX = 1 | AVX2 = 1 | AVX512 = 0 | AVX512_VBMI = 0 | AVX512_VNNI = 0 | FMA = 1 | NEON = 0 | ARM_FMA = 0 | F16C = 1 | FP16_VA = 0 | WASM_SIMD = 0 | BLAS = 1 | SSE3 = 1 | SSSE3 = 1 | VSX = 0 |

# %%
# Load model directly
#from transformers import AutoModel
#llm = AutoModel.from_pretrained("/content/llama-2-13b.Q2_K.gguf")

# %%
#!huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To login, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Token:
# Add token as git credential? (Y/n) n
# Token is valid (permission: read).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
'''from transformers import AutoTokenizer, AutoModelForCausalLM
import torch

#tokenizer = AutoTokenizer.from_pretrained("togethercomputer/LLaMA-2-7B-32K")
#llm = AutoModelForCausalLM.from_pretrained("togethercomputer/LLaMA-2-7B-32K", trust_remote_code=True, torch_dtype=torch.float16)

mn = "meta-llama/Llama-2-7b-hf"
llm = AutoModelForCausalLM.from_pretrained(mn, device_map=0, torch_dtype=torch.bfloat16)'''
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# ...

# %%
'''from langchain.llms import HuggingFacePipeline
import torch

llm = HuggingFacePipeline.from_model_id(
    #model_id = "TheBloke/Llama-2-7b-Chat-GPTQ",
    model_id = "meta-llama/Llama-2-7b-hf",
    task = "text-generation",
    #device=0,
    #device_map = 0,
    #torch_dtype=torch.bfloat16,
    #batch_size = 1,
    #model_kwargs = {"temperature": 0, "max_length": 64}
)'''

# %%
spark_sql = SparkSQL(schema=schema)
toolkit = SparkSQLToolkit(db=spark_sql, llm=llm)
agent_executor = create_spark_sql_agent(llm=llm, toolkit=toolkit, verbose=True)

# %%
agent_executor.run("Describe the stroke_data table")
# Out:
# > Entering new AgentExecutor chain...
# ---------------------------------------------------------------------------
# OutputParserException                     Traceback (most recent call last)
# <ipython-input-61-47b77227d399> in <cell line: 1>()
# ----> 1 agent_executor.run("Describe the stroke_data table")
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/base.py in run(self, callbacks, tags, metadata, *args, **kwargs)
#     505             if len(args) != 1:
#     506                 raise ValueError("`run` supports only one positional argument.")
# --> 507             return self(args[0], callbacks=callbacks, tags=tags, metadata=metadata)[
#     508                 _output_key
#     509             ]
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/base.py in __call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     310         except BaseException as e:
#     311             run_manager.on_chain_error(e)
# ...

# %%
agent_executor.run("How many persons have heart disease?")
# Out:
# > Entering new AgentExecutor chain...
# Llama.generate: prefix-match hit
# ---------------------------------------------------------------------------
# OutputParserException                     Traceback (most recent call last)
# <ipython-input-62-7c1b3e6f491e> in <cell line: 1>()
# ----> 1 agent_executor.run("How many persons have heart disease?")
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/base.py in run(self, callbacks, tags, metadata, *args, **kwargs)
#     505             if len(args) != 1:
#     506                 raise ValueError("`run` supports only one positional argument.")
# --> 507             return self(args[0], callbacks=callbacks, tags=tags, metadata=metadata)[
#     508                 _output_key
#     509             ]
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/base.py in __call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     310         except BaseException as e:
# ...

# %%
agent_executor.run("How many persons have heart disease in stroke_data table in langchain spark db?")
# Out:
# > Entering new AgentExecutor chain...
# Llama.generate: prefix-match hit
# ---------------------------------------------------------------------------
# OutputParserException                     Traceback (most recent call last)
# <ipython-input-63-670de5d429e9> in <cell line: 1>()
# ----> 1 agent_executor.run("How many persons have heart disease in stroke_data table in langchain spark db?")
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/base.py in run(self, callbacks, tags, metadata, *args, **kwargs)
#     505             if len(args) != 1:
#     506                 raise ValueError("`run` supports only one positional argument.")
# --> 507             return self(args[0], callbacks=callbacks, tags=tags, metadata=metadata)[
#     508                 _output_key
#     509             ]
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/base.py in __call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
# ...

# %%
agent_executor.run("How many persons are married?")
# Out:
# > Entering new AgentExecutor chain...
# Llama.generate: prefix-match hit
# ---------------------------------------------------------------------------
# OutputParserException                     Traceback (most recent call last)
# <ipython-input-64-35d7d9c6a81f> in <cell line: 1>()
# ----> 1 agent_executor.run("How many persons are married?")
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/base.py in run(self, callbacks, tags, metadata, *args, **kwargs)
#     505             if len(args) != 1:
#     506                 raise ValueError("`run` supports only one positional argument.")
# --> 507             return self(args[0], callbacks=callbacks, tags=tags, metadata=metadata)[
#     508                 _output_key
#     509             ]
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/base.py in __call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     310         except BaseException as e:
# ...

# %%
agent_executor.run("How many persons are married according to stroke_data table in langchain spark db?")
# Out:
# > Entering new AgentExecutor chain...
# Llama.generate: prefix-match hit
# ---------------------------------------------------------------------------
# OutputParserException                     Traceback (most recent call last)
# <ipython-input-65-a10392a4aa89> in <cell line: 1>()
# ----> 1 agent_executor.run("How many persons are married according to stroke_data table in langchain spark db?")
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/base.py in run(self, callbacks, tags, metadata, *args, **kwargs)
#     505             if len(args) != 1:
#     506                 raise ValueError("`run` supports only one positional argument.")
# --> 507             return self(args[0], callbacks=callbacks, tags=tags, metadata=metadata)[
#     508                 _output_key
#     509             ]
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/base.py in __call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
# ...

# %%
agent_executor.run("Tell me the number of records having heart_disease=1 in stroke_data table in langchain spark db?")
# Out:
# > Entering new AgentExecutor chain...
# Llama.generate: prefix-match hit
# ---------------------------------------------------------------------------
# OutputParserException                     Traceback (most recent call last)
# <ipython-input-66-3097c3af29fd> in <cell line: 1>()
# ----> 1 agent_executor.run("Tell me the number of records having heart_disease=1 in stroke_data table in langchain spark db?")
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/base.py in run(self, callbacks, tags, metadata, *args, **kwargs)
#     505             if len(args) != 1:
#     506                 raise ValueError("`run` supports only one positional argument.")
# --> 507             return self(args[0], callbacks=callbacks, tags=tags, metadata=metadata)[
#     508                 _output_key
#     509             ]
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/base.py in __call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
# ...
